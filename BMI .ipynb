# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/srishtichauhan/Desktop/BMIfinal.csv")

# %%
df['BMI'] = ((df['Weight(kg)'])*10000)/((df['Height(cm)'])**2)

# %%
df
# Out:
#                 Name Branch  Gender  Height(cm)  Weight(kg)  Age        BMI
# 0       Stuti Tiwari   CSAI  Female         162          49   18  18.670934
# 1               Nysa   CSAI  Female         167          50   19  17.928215
# 2     Archana Singh    CSAI  Female         167          50   19  17.928215
# 3         Mahi gupta   CSAI  Female         162          53   19  20.195092
# 4          Hemanthi    CSAI  Female         166          60   19  21.773842
# ..               ...    ...     ...         ...         ...  ...        ...
# 111            Reena    CSE  Female         159          50   19  19.777699
# 112  Vartika chauhan   CSAI  Female         178          45   16  14.202752
# 113    Aryan Sharma     CSE    Male         170          66   19  22.837370
# 114           Ayushi    BBA  Female         154          42   19  17.709563
# 115   Ipshita Tandon    CSE  Female         152          45   19  19.477147
#
# [116 rows x 7 columns]

# %%
# 18.5 > undernourished
# 18.5 - 24.9 = healthy
# 25 - 29.9 = overweight
# 30 < obese

# %%
df.describe()
# Out:
#        Height(cm)  Weight(kg)         Age         BMI
# count  116.000000  116.000000  116.000000  116.000000
# mean   169.017241   59.456897   19.051724   21.031679
# std     23.926693   13.289677    3.635202    3.806519
# min    144.000000   35.000000   16.000000    3.047245
# 25%    159.000000   49.750000   18.000000   18.590125
# 50%    167.000000   56.000000   19.000000   20.933940
# 75%    176.000000   67.250000   19.000000   23.183919
# max    401.000000  103.000000   57.000000   34.020346

# %%
BMI = df['BMI'].values.tolist()

# %%
cat = []
for i in range(0, len(BMI)):
    if (BMI[i] < 18.5):
        cat.append("Underweight")
    elif (18.5 <= BMI[i] <= 24.9):
        cat.append("Healthy")
    elif (25 <= BMI[i] <= 29.9):
        cat.append("Overweight")
    else:
        cat.append("Obese")

# %% [markdown]
# # GENDER BASED PLOTS

# %%
ds1 = df[df.Gender == "Female"]
ds2 = df[df.Gender == "Male"]
print(ds1.groupby(["Weight Category"]).count().plot(kind = "pie", y = "BMI", title = "FEMALE WEIGHT CATEGORY DISTRIBUTION")) # FEMALE
print(ds2.groupby(["Weight Category"]).count().plot(kind = "pie", y = "BMI", title = "MALE WEIGHT CATEGORY DISTRIBUTION")) # MALE
# Out:
# AxesSubplot(0.22375,0.11;0.5775x0.77)
# AxesSubplot(0.22375,0.11;0.5775x0.77)

# %% [markdown]
# # BRANCH BASED PLOTS

# %%
b1 = df[df.Branch == "CSAI"]
b2 = df[df.Branch == "ECAI"]
b3 = df[df.Branch == "ARCH"]
b4 = df[df.Branch == "MECH"]
b5 = df[df.Branch == "CSE"]
b6 = df[df.Branch == "BBA"]
b7 = df[df.Branch == "MEDICAL"]
b8 = df[df.Branch == 'ECE']
b9 = df[df.Branch == 'AIML']
b10 = df[df.Branch == 'IT']
print(b1.groupby(["Weight Category"]).count().plot(kind = "pie", y = "BMI", title = "CSAI"))
print(b2.groupby(["Weight Category"]).count().plot(kind = "pie", y = "BMI", title = "ECAI"))
print(b3.groupby(["Weight Category"]).count().plot(kind = "pie", y = "BMI", title = "ARCH"))
print(b4.groupby(["Weight Category"]).count().plot(kind = "pie", y = "BMI", title = "MECH"))
print(b5.groupby(["Weight Category"]).count().plot(kind = "pie", y = "BMI", title = "CSE"))
print(b6.groupby(["Weight Category"]).count().plot(kind = "pie", y = "BMI", title = "BBA"))
print(b7.groupby(["Weight Category"]).count().plot(kind = "pie", y = "BMI", title = "MEDICAL"))
print(b8.groupby(["Weight Category"]).count().plot(kind = "pie", y = "BMI", title = "ECE"))
print(b9.groupby(["Weight Category"]).count().plot(kind = "pie", y = "BMI", title = "AIML"))
print(b10.groupby(["Weight Category"]).count().plot(kind = "pie", y = "BMI", title = "IT"))
# Out:
# AxesSubplot(0.22375,0.11;0.5775x0.77)
# AxesSubplot(0.22375,0.11;0.5775x0.77)
# AxesSubplot(0.22375,0.11;0.5775x0.77)
# AxesSubplot(0.22375,0.11;0.5775x0.77)
# AxesSubplot(0.22375,0.11;0.5775x0.77)
# AxesSubplot(0.22375,0.11;0.5775x0.77)
# AxesSubplot(0.22375,0.11;0.5775x0.77)
# AxesSubplot(0.22375,0.11;0.5775x0.77)
# AxesSubplot(0.22375,0.11;0.5775x0.77)
# AxesSubplot(0.22375,0.11;0.5775x0.77)

# %% [markdown]
# # AGE BASED PLOTS

# %%
a1 = df[df.Age == 18]
a2 = df[df.Age == 19]
a3 = df[df.Age == 20]
print(a1.groupby(["Weight Category"]).count().plot(kind = "pie", y = "BMI", title = "AGE = 18"))
print(a2.groupby(["Weight Category"]).count().plot(kind = "pie", y = "BMI", title = "AGE = 19"))
print(a3.groupby(["Weight Category"]).count().plot(kind = "pie", y = "BMI", title = "AGE = 20"))
# Out:
# AxesSubplot(0.22375,0.11;0.5775x0.77)
# AxesSubplot(0.22375,0.11;0.5775x0.77)
# AxesSubplot(0.22375,0.11;0.5775x0.77)
